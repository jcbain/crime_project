# %%
import pandas as pd
import numpy as np
import re
import glob

# %% [markdown]
# Dammit Excel! Well, I now know that my first task is to clean up the files and get them into a working format. It appears as if there is a lot of superfluous information... someone was trying to impress a date with their excel talent. Let's create a function `make_df()` that will take a parameter to read in a sheet from my `orig_data` directory, extract the headers and apply those to the pertinent data. This is more complicated that what it sounds as they have taken the headers and split them among two rows. Fortunately they were consistent in their pattern so this function should work for the majority of the excel files that we will be working with.

# %%
def make_df(sheet): 
    head_col = []
    
    file = pd.read_excel(sheet,header=None) # read in the file 
    head_col.extend(file.loc[3][0:2]) # extract the first two column headers and append it to a list
    file2 = pd.read_excel(sheet,header=None,skiprows=list(range(0,4))) # read in the file again as these rows weren't read in the first time, this time taking out the original rows
    head_col.extend(file2.loc[0][2:]) # append those to a list
    
    x = [y.replace('\n', '_') for y in head_col] # find all instances of \n in the file and replace with _
    z = [y.replace(' ', '_') for y in x ] # find all blanks and replace
    header_col = [x.lower() for x in z] # change the header column to lowercase
    
    fin_file = pd.read_excel(sheet,skiprows=list(range(0,7)),header=None) # read in the final file format
    fin_file.columns = header_col # attach the header column
    return fin_file

# %%
sheets = glob.glob('orig_data/*')
df = make_df(sheets[3])
df
# Out:
#                                      offense_category  total_victims1  \
# 0                                    Assault Offenses         1165909
# 1                                   Homicide Offenses            3854
# 2                          Human Trafficking Offenses              57
# 3                                Kidnapping/Abduction           15552
# 4                                        Sex Offenses           70928
# 5                           Sex Offenses, Nonforcible            5484
# 6                             Crimes Against Property         2770816
# 7                                               Arson           10614
# 8                                             Bribery             222
# 9                        Burglary/Breaking & Entering          447058
# 10                             Counterfeiting/Forgery           36126
# 11                       Destruction/Damage/Vandalism          579916
# 12                                       Embezzlement            3864
# 13                                Extortion/Blackmail            1745
# 14                                     Fraud Offenses          247032
# 15                             Larceny/Theft Offenses         1175569
# 16                                Motor Vehicle Theft          162068
# 17                                            Robbery           74862
# 18                           Stolen Property Offenses           31740
# 19  1This table includes only data for individual ...             NaN
#
#        male   female  unknown
# 0    500233   657421     8255
# 1      2872      955       27
# 2         1       55        1
# 3      3653    11849       50
# 4     10821    59875      232
# 5       590     4888        6
# 6   1421947  1323445    25424
# 7      5549     4369      696
# 8       150       67        5
# 9    237120   206557     3381
# 10    18052    17113      961
# 11   285596   289513     4807
# 12     2183     1632       49
# 13      932      806        7
# 14   110249   134129     2654
# 15   600114   565835     9620
# 16    95759    65098     1211
# 17    48932    25749      181
# 18    17311    12577     1852
# 19      NaN      NaN      NaN

# %% [markdown]
# Looks like it didn't work for all tables. Seems as if there are some files that start with only 2 unnecessary columns. I will need to see if I can clean this up so that I don't have two functions doing the same thing.

# %%
def make_df(sheet): 
    head_col = []
    
    file = pd.read_excel(sheet,header=None) # read in the file 
    head_col.extend(file.loc[2][0:2]) # extract the first two column headers and append it to a list
    file2 = pd.read_excel(sheet,header=None,skiprows=list(range(0,3))) # read in the file again as these rows weren't read in the first time, this time taking out the original rows
    head_col.extend(file2.loc[0][2:]) # append those to a list
    
    x = [y.replace('\n', '_') for y in head_col] # find all instances of \n in the file and replace with _
    z = [y.replace(' ', '_') for y in x ] # find all blanks and replace
    header_col = [x.lower() for x in z] # change the header column to lowercase
    
    fin_file = pd.read_excel(sheet,skiprows=list(range(0,7)),header=None) # read in the final file format
    fin_file.columns = header_col # attach the header column
    return fin_file

# %%
df = make_df(sheets[1])
df
# Out:
#                                      offense_category  total_victims1  \
# 0                                   Homicide Offenses            3427
# 1                          Human Trafficking Offenses              57
# 2                                Kidnapping/Abduction           14894
# 3                                        Sex Offenses           66567
# 4                           Sex Offenses, Nonforcible            5191
# 5                             Crimes Against Property           64357
# 6                                             Robbery           64357
# 7   1The relationship of a victim to an offender i...             NaN
# 8   2Victims were related to all offenders, whethe...             NaN
# 9   3Victims were related to at least one of the m...             NaN
# 10  4Victims knew, but were not related to, one or...             NaN
# 11  5Victims were mutual combatants (victim was of...             NaN
#
#     family_member2  family_member_and_other3  known_to_victim_and_other4  \
# 0              602                        46                        1317
# 1                0                         0                          28
# 2             3226                       179                        7969
# 3            17770                       607                       35497
# 4             1066                        52                        3624
# 5              569                       170                       12431
# 6              569                       170                       12431
# 7              NaN                       NaN                         NaN
# 8              NaN                       NaN                         NaN
# 9              NaN                       NaN                         NaN
# 10             NaN                       NaN                         NaN
# 11             NaN                       NaN                         NaN
#
#     stranger  all_other5
# 0        391        1071
# 1         24           5
# 2       1631        1889
# 3       4911        7782
# 4         95         354
# 5      27370       23817
# 6      27370       23817
# 7        NaN         NaN
# 8        NaN         NaN
# 9        NaN         NaN
# 10       NaN         NaN
# 11       NaN         NaN
